# %%
# example of a ordinal encoding
from numpy import asarray
from sklearn.preprocessing import OrdinalEncoder

data = asarray([['red'], ['green'], ['blue']])
result   = OrdinalEncoder().fit_transform(data)

# %%
result
# Out:
# array([[2.],
#        [1.],
#        [0.]])

# %%
import pandas as pd

# %%
df = pd.read_csv("Ecommerce Customers")

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df['Avatar_encoding'] = OrdinalEncoder().fit_transform(df.Avatar.values.reshape(-1,1))

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df.Avatar_encoding.max() #0 - 137
# Out:
# 137.0

# %%
df['Avatar'].value_counts()
# Out:
# SlateBlue               7
# Cyan                    7
# CadetBlue               7
# GreenYellow             7
# Teal                    7
#                        ..
# MediumPurple            1
# CornflowerBlue          1
# LightGoldenRodYellow    1
# PowderBlue              1
# LawnGreen               1
# Name: Avatar, Length: 138, dtype: int64

# %%
len(df['Avatar'].unique())
# Out:
# 138

# %%
py_dict = {'name':['arun','akash','jon','justin'],
          'age':[24,45,66,34],
          'color':['low','high','high','meduim']}

# %%
df1 = pd.DataFrame(py_dict)

# %%
df1['color_encoding'] = OrdinalEncoder().fit_transform(df1.color.values.reshape(-1,1))

# %%
df1
# Out:
#      name  age   color  color_encoding
# 0    arun   24     low             1.0
# 1   akash   45    high             0.0
# 2     jon   66    high             0.0
# 3  justin   34  meduim             2.0

# %%
df3 = pd.get_dummies(df1.color)

# %%
df3
# Out:
#    high  low  meduim
# 0     0    1       0
# 1     1    0       0
# 2     1    0       0
# 3     0    0       1

# %%
from sklearn.preprocessing import OneHotEncoder
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-055db0fe786e> in <module>
#       1 from sklearn.preprocessing import OneHotEncoder
# ----> 2 df1['color encode with one'] = OneHotEncoder().fit_transform(df1.color.values.reshape(-1,1))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
# ...

# %%
df1['color encode with one'] = OneHotEncoder(drop='first', sparse=False).fit_transform(df1['color'].values.reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'color encode with one'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1
# Out:
#      name  age   color  color_encoding
# 0    arun   24     low             1.0
# 1   akash   45    high             0.0
# 2     jon   66    high             0.0
# 3  justin   34  meduim             2.0

# %%
# example of a dummy variable encoding
from numpy import asarray
from sklearn.preprocessing import OneHotEncoder
# define data
data = asarray([['red'], ['green'], ['blue']])
print(data)
# define one hot encoding
encoder = OneHotEncoder(drop='first', sparse=False)
# transform data
onehot = encoder.fit_transform(data)
print(onehot)
# Out:
# [['red']
#  ['green']
#  ['blue']]
# [[0. 1.]
#  [1. 0.]
#  [0. 0.]]

# %%
df1['color']=OneHotEncoder(drop='first', sparse=False).fit_transform(df1['color'].values.reshape(-1,1))

# %%
df1
# Out:
#      name  age  color  color_encoding
# 0    arun   24    1.0             1.0
# 1   akash   45    0.0             0.0
# 2     jon   66    0.0             0.0
# 3  justin   34    0.0             2.0

# %%
df1
# Out:
#      name  age   color
# 0    arun   24     low
# 1   akash   45    high
# 2     jon   66    high
# 3  justin   34  meduim

# %%
OneHotEncoder(drop='first',sparse=False).fit_transform(df1['color'].values.reshape(-1,1))
# Out:
# array([[1., 0.],
#        [0., 0.],
#        [0., 0.],
#        [0., 1.]])

# %%
df1
# Out:
#      name  age   color
# 0    arun   24     low
# 1   akash   45    high
# 2     jon   66    high
# 3  justin   34  meduim

# %%
df2 = pd.get_dummies(df1.color)

# %%
df4 = pd.concat([df1,df2],axis=1)

# %%
df4
# Out:
#      name  age   color  high  low  meduim
# 0    arun   24     low     0    1       0
# 1   akash   45    high     1    0       0
# 2     jon   66    high     1    0       0
# 3  justin   34  meduim     0    0       1
