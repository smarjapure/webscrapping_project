# %%
matplotlib and seaborn

are usefull for visualization


why visualization

visualization 2 level 

1. self visual -- for making benchmark /standard data for ML
2.for client for taking desicion

# %%
matplotlib

# %%
line graph
Bar graph
scatter plot
Histogram
pie chart

# %%
from matplotlib import pyplot as plt

# %%
x = [10,20,30]
y = [30,40,50]

# %%
plt.plot(x,y)
plt.title("My first graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend("Salary")
plt.show()

# %%
age
salary

# %%
#scatter plot

# %%
#Note :This plot is used for outlier detection

# %%
x = [1,4,8,3,5,7,8]

# %%
y = [3,6,8,4,2,5,7]

# %%
plt.scatter(x,y)

# %%
import pandas as pd

# %%
df = pd.read_csv("weather.csv")

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
plt.scatter(df['Data.Temperature.Avg Temp'],df['Data.Wind.Direction'])

# %%
pip install tabula
# Out:
# ...
#   Created wheel for tabula: filename=tabula-1.0.5-py3-none-any.whl size=10589 sha256=40a3d82d58be01103d2173e13045a84d31c5b2ae0ad7ab8e962b088f3ea12e85
#   Stored in directory: c:\users\kanti\appdata\local\pip\cache\wheels\2e\51\35\aa182d12911ffd4045285cffccb0e130b74e9b0c083310c161
# Successfully built tabula
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                            VersionNote: you may need to restart the kernel to use updated packages.
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# aniso8601                          9.0.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asgiref                            3.4.1
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
#
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# ...

# %%
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
plt.scatter(df['Date.Year'],df['Data.Temperature.Avg Temp'])

# %%
df.isnull().sum()
# Out:
# Data.Precipitation           0
# Date.Full                    0
# Date.Month                   0
# Date.Week of                 0
# Date.Year                    0
# Station.City                 0
# Station.Code                 0
# Station.Location             0
# Station.State                0
# Data.Temperature.Avg Temp    0
# Data.Temperature.Max Temp    0
# Data.Temperature.Min Temp    0
# Data.Wind.Direction          0
# Data.Wind.Speed              0
# dtype: int64

# %%
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
x = [10,20,30,50,]

# %%
y = [5,8,9,10]

# %%
plt.scatter(x,y)

# %%
variable relation

outliers

# %%
Bar Graph and Histogram

# %%
plt.bar([1,5,3,7,9],[4,8,3,7,6])
# Out:
# <BarContainer object of 5 artists>

# %%
bjp = [1,3,5,7,7]
congress=  [3,6,8,3,6]

# %%
plt.bar(bjp,congress)
# Out:
# <BarContainer object of 5 artists>

# %%
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
class_data = [10,40,10,50,20,10,40,10]

# %%
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
plt.hist(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-3c15afa5b17c> in <module>
# ----> 1 plt.hist(df)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2603         orientation='vertical', rwidth=None, log=False, color=None,
#    2604         label=None, stacked=False, *, data=None, **kwargs):
# -> 2605     return gca().hist(
#    2606         x, bins=bins, range=range, density=density, weights=weights,
#    2607         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
class_age = [10,60,10,40,30,67,34,57,23,56]

# %%
bins = [0,10,20,30,40,50,60]

# %%
plt.hist(class_age,bins)
# Out:
# (array([0., 2., 1., 2., 1., 3.]),
#  array([ 0, 10, 20, 30, 40, 50, 60]),
#  <a list of 6 Patch objects>)

# %%
pie chart

# %%
pythonbatches = [50,45,81,100]

name = ['python23','python22','python25','python26']

# %%
plt.pie(pythonbatches,labels=name,shadow=True,explode=(0.3,0,0,0))
plt.savefig('graph.jpg')
