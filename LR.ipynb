# %%
import pandas as pd

# %%
df = pd.read_csv('advertising.csv')

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.shape
# Out:
# (200, 4)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['TV'],df['Sales'])
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['Radio'],df['Sales'])
plt.xlabel('Radio')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['Newspaper'],df['Sales'])
plt.xlabel('Newspaper')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['Sales'],df['TV'])
plt.xlabel('Sales')
plt.ylabel('TV')
plt.show()

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
data loading
ETL pipeline
api
csv file
excel
Dataware Datamart
AWS s3
RDS 


BA /Manager/Domain expert
model --benchmark


excel 

front page 

explanation -- feature -- 
weather ---

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
x = df['TV'].values.reshape(-1,1)

# %%
x.shape
# Out:
# (200, 1)

# %%
y = df['Sales'].values.reshape(-1,1)

# %%
y
# Out:
# array([[22.1],
#        [10.4],
#        [12. ],
#        [16.5],
#        [17.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [15.6],
#        [12.6],
#        [17.4],
#        [ 9.2],
#        [13.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [17.5],
#        [ 5.6],
#        [20.5],
#        [ 9.7],
#        [17. ],
#        [15. ],
#        [20.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [13.2],
#        [17.4],
#        [11.9],
#        [17.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [17.9],
#        [ 8.5],
#        [16.1],
#        [10.6],
#        [23.2],
#        [19.8],
#        [ 9.7],
#        [16.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
#        [23.8],
#        [18.4],
#        [ 8.1],
#        [24.2],
#        [20.7],
#        [14. ],
#        [16. ],
#        [11.3],
#        [11. ],
#        [13.4],
#        [18.9],
#        [22.3],
#        [18.3],
#        [12.4],
#        [ 8.8],
#        [11. ],
#        [17. ],
#        [ 8.7],
#        [ 6.9],
#        [14.2],
#        [ 5.3],
#        [11. ],
#        [11.8],
#        [17.3],
#        [11.3],
#        [13.6],
#        [21.7],
#        [20.2],
#        [12. ],
#        [16. ],
#        [12.9],
#        [16.7],
#        [14. ],
#        [ 7.3],
#        [19.4],
#        [22.2],
#        [11.5],
#        [16.9],
#        [16.7],
#        [20.5],
#        [25.4],
#        [17.2],
#        [16.7],
#        [23.8],
#        [19.8],
#        [19.7],
#        [20.7],
#        [15. ],
#        [ 7.2],
#        [12. ],
#        [ 5.3],
#        [19.8],
#        [18.4],
#        [21.8],
#        [17.1],
#        [20.9],
#        [14.6],
#        [12.6],
#        [12.2],
#        [ 9.4],
#        [15.9],
#        [ 6.6],
#        [15.5],
#        [ 7. ],
#        [16.6],
#        [15.2],
#        [19.7],
#        [10.6],
#        [ 6.6],
#        [11.9],
#        [24.7],
#        [ 9.7],
#        [ 1.6],
#        [17.7],
#        [ 5.7],
#        [19.6],
#        [10.8],
#        [11.6],
#        [ 9.5],
#        [20.8],
#        [ 9.6],
#        [20.7],
#        [10.9],
#        [19.2],
#        [20.1],
#        [10.4],
#        [12.3],
#        [10.3],
#        [18.2],
#        [25.4],
#        [10.9],
#        [10.1],
#        [16.1],
#        [11.6],
#        [16.6],
#        [16. ],
#        [20.6],
#        [ 3.2],
#        [15.3],
#        [10.1],
#        [ 7.3],
#        [12.9],
#        [16.4],
#        [13.3],
#        [19.9],
#        [18. ],
#        [11.9],
#        [16.9],
#        [ 8. ],
#        [17.2],
#        [17.1],
#        [20. ],
#        [ 8.4],
#        [17.5],
#        [ 7.6],
#        [16.7],
#        [16.5],
#        [27. ],
#        [20.2],
#        [16.7],
#        [16.8],
#        [17.6],
#        [15.5],
#        [17.2],
#        [ 8.7],
#        [26.2],
#        [17.6],
#        [22.6],
#        [10.3],
#        [17.3],
#        [20.9],
#        [ 6.7],
#        [10.8],
#        [11.9],
#        [ 5.9],
#        [19.6],
#        [17.3],
#        [ 7.6],
#        [14. ],
#        [14.8],
#        [25.5],
#        [18.4]])

# %%
y.shape
# Out:
# (200, 1)

# %%
temp = df['TV'].values.reshape(-1,1)

# %%
temp
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
#        [198.9],
#        [  7.3],
#        [136.2],
#        [210.8],
#        [210.7],
#        [ 53.5],
#        [261.3],
#        [239.3],
#        [102.7],
#        [131.1],
#        [ 69. ],
#        [ 31.5],
#        [139.3],
#        [237.4],
#        [216.8],
#        [199.1],
#        [109.8],
#        [ 26.8],
#        [129.4],
#        [213.4],
#        [ 16.9],
#        [ 27.5],
#        [120.5],
#        [  5.4],
#        [116. ],
#        [ 76.4],
#        [239.8],
#        [ 75.3],
#        [ 68.4],
#        [213.5],
#        [193.2],
#        [ 76.3],
#        [110.7],
#        [ 88.3],
#        [109.8],
#        [134.3],
#        [ 28.6],
#        [217.7],
#        [250.9],
#        [107.4],
#        [163.3],
#        [197.6],
#        [184.9],
#        [289.7],
#        [135.2],
#        [222.4],
#        [296.4],
#        [280.2],
#        [187.9],
#        [238.2],
#        [137.9],
#        [ 25. ],
#        [ 90.4],
#        [ 13.1],
#        [255.4],
#        [225.8],
#        [241.7],
#        [175.7],
#        [209.6],
#        [ 78.2],
#        [ 75.1],
#        [139.2],
#        [ 76.4],
#        [125.7],
#        [ 19.4],
#        [141.3],
#        [ 18.8],
#        [224. ],
#        [123.1],
#        [229.5],
#        [ 87.2],
#        [  7.8],
#        [ 80.2],
#        [220.3],
#        [ 59.6],
#        [  0.7],
#        [265.2],
#        [  8.4],
#        [219.8],
#        [ 36.9],
#        [ 48.3],
#        [ 25.6],
#        [273.7],
#        [ 43. ],
#        [184.9],
#        [ 73.4],
#        [193.7],
#        [220.5],
#        [104.6],
#        [ 96.2],
#        [140.3],
#        [240.1],
#        [243.2],
#        [ 38. ],
#        [ 44.7],
#        [280.7],
#        [121. ],
#        [197.6],
#        [171.3],
#        [187.8],
#        [  4.1],
#        [ 93.9],
#        [149.8],
#        [ 11.7],
#        [131.7],
#        [172.5],
#        [ 85.7],
#        [188.4],
#        [163.5],
#        [117.2],
#        [234.5],
#        [ 17.9],
#        [206.8],
#        [215.4],
#        [284.3],
#        [ 50. ],
#        [164.5],
#        [ 19.6],
#        [168.4],
#        [222.4],
#        [276.9],
#        [248.4],
#        [170.2],
#        [276.7],
#        [165.6],
#        [156.6],
#        [218.5],
#        [ 56.2],
#        [287.6],
#        [253.8],
#        [205. ],
#        [139.5],
#        [191.1],
#        [286. ],
#        [ 18.7],
#        [ 39.5],
#        [ 75.5],
#        [ 17.2],
#        [166.8],
#        [149.7],
#        [ 38.2],
#        [ 94.2],
#        [177. ],
#        [283.6],
#        [232.1]])

# %%
x
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
#        [198.9],
#        [  7.3],
#        [136.2],
#        [210.8],
#        [210.7],
#        [ 53.5],
#        [261.3],
#        [239.3],
#        [102.7],
#        [131.1],
#        [ 69. ],
#        [ 31.5],
#        [139.3],
#        [237.4],
#        [216.8],
#        [199.1],
#        [109.8],
#        [ 26.8],
#        [129.4],
#        [213.4],
#        [ 16.9],
#        [ 27.5],
#        [120.5],
#        [  5.4],
#        [116. ],
#        [ 76.4],
#        [239.8],
#        [ 75.3],
#        [ 68.4],
#        [213.5],
#        [193.2],
#        [ 76.3],
#        [110.7],
#        [ 88.3],
#        [109.8],
#        [134.3],
#        [ 28.6],
#        [217.7],
#        [250.9],
#        [107.4],
#        [163.3],
#        [197.6],
#        [184.9],
#        [289.7],
#        [135.2],
#        [222.4],
#        [296.4],
#        [280.2],
#        [187.9],
#        [238.2],
#        [137.9],
#        [ 25. ],
#        [ 90.4],
#        [ 13.1],
#        [255.4],
#        [225.8],
#        [241.7],
#        [175.7],
#        [209.6],
#        [ 78.2],
#        [ 75.1],
#        [139.2],
#        [ 76.4],
#        [125.7],
#        [ 19.4],
#        [141.3],
#        [ 18.8],
#        [224. ],
#        [123.1],
#        [229.5],
#        [ 87.2],
#        [  7.8],
#        [ 80.2],
#        [220.3],
#        [ 59.6],
#        [  0.7],
#        [265.2],
#        [  8.4],
#        [219.8],
#        [ 36.9],
#        [ 48.3],
#        [ 25.6],
#        [273.7],
#        [ 43. ],
#        [184.9],
#        [ 73.4],
#        [193.7],
#        [220.5],
#        [104.6],
#        [ 96.2],
#        [140.3],
#        [240.1],
#        [243.2],
#        [ 38. ],
#        [ 44.7],
#        [280.7],
#        [121. ],
#        [197.6],
#        [171.3],
#        [187.8],
#        [  4.1],
#        [ 93.9],
#        [149.8],
#        [ 11.7],
#        [131.7],
#        [172.5],
#        [ 85.7],
#        [188.4],
#        [163.5],
#        [117.2],
#        [234.5],
#        [ 17.9],
#        [206.8],
#        [215.4],
#        [284.3],
#        [ 50. ],
#        [164.5],
#        [ 19.6],
#        [168.4],
#        [222.4],
#        [276.9],
#        [248.4],
#        [170.2],
#        [276.7],
#        [165.6],
#        [156.6],
#        [218.5],
#        [ 56.2],
#        [287.6],
#        [253.8],
#        [205. ],
#        [139.5],
#        [191.1],
#        [286. ],
#        [ 18.7],
#        [ 39.5],
#        [ 75.5],
#        [ 17.2],
#        [166.8],
#        [149.7],
#        [ 38.2],
#        [ 94.2],
#        [177. ],
#        [283.6],
#        [232.1]])

# %%
y
# Out:
# array([[22.1],
#        [10.4],
#        [12. ],
#        [16.5],
#        [17.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [15.6],
#        [12.6],
#        [17.4],
#        [ 9.2],
#        [13.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [17.5],
#        [ 5.6],
#        [20.5],
#        [ 9.7],
#        [17. ],
#        [15. ],
#        [20.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [13.2],
#        [17.4],
#        [11.9],
#        [17.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [17.9],
#        [ 8.5],
#        [16.1],
#        [10.6],
#        [23.2],
#        [19.8],
#        [ 9.7],
#        [16.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
#        [23.8],
#        [18.4],
#        [ 8.1],
#        [24.2],
#        [20.7],
#        [14. ],
#        [16. ],
#        [11.3],
#        [11. ],
#        [13.4],
#        [18.9],
#        [22.3],
#        [18.3],
#        [12.4],
#        [ 8.8],
#        [11. ],
#        [17. ],
#        [ 8.7],
#        [ 6.9],
#        [14.2],
#        [ 5.3],
#        [11. ],
#        [11.8],
#        [17.3],
#        [11.3],
#        [13.6],
#        [21.7],
#        [20.2],
#        [12. ],
#        [16. ],
#        [12.9],
#        [16.7],
#        [14. ],
#        [ 7.3],
#        [19.4],
#        [22.2],
#        [11.5],
#        [16.9],
#        [16.7],
#        [20.5],
#        [25.4],
#        [17.2],
#        [16.7],
#        [23.8],
#        [19.8],
#        [19.7],
#        [20.7],
#        [15. ],
#        [ 7.2],
#        [12. ],
#        [ 5.3],
#        [19.8],
#        [18.4],
#        [21.8],
#        [17.1],
#        [20.9],
#        [14.6],
#        [12.6],
#        [12.2],
#        [ 9.4],
#        [15.9],
#        [ 6.6],
#        [15.5],
#        [ 7. ],
#        [16.6],
#        [15.2],
#        [19.7],
#        [10.6],
#        [ 6.6],
#        [11.9],
#        [24.7],
#        [ 9.7],
#        [ 1.6],
#        [17.7],
#        [ 5.7],
#        [19.6],
#        [10.8],
#        [11.6],
#        [ 9.5],
#        [20.8],
#        [ 9.6],
#        [20.7],
#        [10.9],
#        [19.2],
#        [20.1],
#        [10.4],
#        [12.3],
#        [10.3],
#        [18.2],
#        [25.4],
#        [10.9],
#        [10.1],
#        [16.1],
#        [11.6],
#        [16.6],
#        [16. ],
#        [20.6],
#        [ 3.2],
#        [15.3],
#        [10.1],
#        [ 7.3],
#        [12.9],
#        [16.4],
#        [13.3],
#        [19.9],
#        [18. ],
#        [11.9],
#        [16.9],
#        [ 8. ],
#        [17.2],
#        [17.1],
#        [20. ],
#        [ 8.4],
#        [17.5],
#        [ 7.6],
#        [16.7],
#        [16.5],
#        [27. ],
#        [20.2],
#        [16.7],
#        [16.8],
#        [17.6],
#        [15.5],
#        [17.2],
#        [ 8.7],
#        [26.2],
#        [17.6],
#        [22.6],
#        [10.3],
#        [17.3],
#        [20.9],
#        [ 6.7],
#        [10.8],
#        [11.9],
#        [ 5.9],
#        [19.6],
#        [17.3],
#        [ 7.6],
#        [14. ],
#        [14.8],
#        [25.5],
#        [18.4]])

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[0.05546477]])

# %%
model.intercept_
# Out:
# array([6.97482149])

# %%
94.2*0.05546477+6.97482149
# Out:
# 12.199602824

# %%
model

# %%
plt.scatter(df['TV'],df['Sales'])
plt.plot(df['TV'],model.predict(x),color='blue',linewidth=9)

# %%
model.score(x,y)
# Out:
# 0.8121757029987414

# %%
y_pred = model.predict(x)

# %%
y_pred
# Out:
# array([[19.73726517],
#        [ 9.44300377],
#        [ 7.92881554],
#        [15.37773421],
#        [17.00285199],
#        [ 7.45736499],
#        [10.16404579],
#        [13.6416869 ],
#        [ 7.45181851],
#        [18.05668263],
#        [10.64104282],
#        [18.88310771],
#        [ 8.29488303],
#        [12.38263661],
#        [18.29518114],
#        [17.81263764],
#        [10.73533293],
#        [22.5826079 ],
#        [10.8129836 ],
#        [15.14478218],
#        [19.08832736],
#        [20.142158  ],
#        [ 7.70695646],
#        [19.63742859],
#        [10.43027669],
#        [21.55650964],
#        [14.90073719],
#        [20.29191288],
#        [20.77445638],
#        [10.89063428],
#        [23.22045276],
#        [13.23679407],
#        [12.36599718],
#        [21.70626452],
#        [12.28280002],
#        [23.09843026],
#        [21.77836873],
#        [11.11803984],
#        [ 9.3653531 ],
#        [19.62078916],
#        [18.20643751],
#        [16.79208586],
#        [23.2592781 ],
#        [18.4504825 ],
#        [ 8.36698723],
#        [16.6867028 ],
#        [11.9500114 ],
#        [20.28081992],
#        [19.57641734],
#        [10.68541463],
#        [18.05668263],
#        [12.54348444],
#        [18.97739782],
#        [17.10268858],
#        [21.54541669],
#        [18.00676433],
#        [ 7.37971431],
#        [14.52912323],
#        [18.6667951 ],
#        [18.66124863],
#        [ 9.94218671],
#        [21.46776601],
#        [20.24754106],
#        [12.67105342],
#        [14.2462529 ],
#        [10.80189065],
#        [ 8.72196176],
#        [14.70106401],
#        [20.142158  ],
#        [18.99958373],
#        [18.01785729],
#        [13.06485329],
#        [ 8.46127734],
#        [14.15196279],
#        [18.81100351],
#        [ 7.91217611],
#        [ 8.50010268],
#        [13.65832633],
#        [ 7.27433125],
#        [13.40873486],
#        [11.21232995],
#        [20.27527345],
#        [11.1513187 ],
#        [10.76861179],
#        [18.81654998],
#        [17.69061514],
#        [11.20678348],
#        [13.11477158],
#        [11.87236072],
#        [13.06485329],
#        [14.42374016],
#        [ 8.56111392],
#        [19.04950202],
#        [20.8909324 ],
#        [12.93173784],
#        [16.03221851],
#        [17.93466013],
#        [17.23025755],
#        [23.04296549],
#        [14.47365846],
#        [19.31018644],
#        [23.41457946],
#        [22.51605017],
#        [17.39665186],
#        [20.18652981],
#        [14.62341334],
#        [ 8.36144075],
#        [11.98883674],
#        [ 7.70140998],
#        [21.14052387],
#        [19.49876666],
#        [20.38065651],
#        [16.71998166],
#        [18.60023738],
#        [11.31216654],
#        [11.14022575],
#        [14.69551754],
#        [11.21232995],
#        [13.94674314],
#        [ 8.05083804],
#        [14.81199356],
#        [ 8.01755917],
#        [19.39893007],
#        [13.80253473],
#        [19.70398631],
#        [11.81134947],
#        [ 7.4074467 ],
#        [11.42309608],
#        [19.19371042],
#        [10.28052181],
#        [ 7.01364683],
#        [21.68407862],
#        [ 7.44072556],
#        [19.16597804],
#        [ 9.02147152],
#        [ 9.6537699 ],
#        [ 8.39471961],
#        [22.15552917],
#        [ 9.35980662],
#        [17.23025755],
#        [11.04593564],
#        [17.71834753],
#        [19.20480338],
#        [12.77643648],
#        [12.31053241],
#        [14.75652879],
#        [20.29191288],
#        [20.46385367],
#        [ 9.08248277],
#        [ 9.45409673],
#        [22.54378256],
#        [13.68605872],
#        [17.93466013],
#        [16.47593667],
#        [17.39110538],
#        [ 7.20222705],
#        [12.18296344],
#        [15.2834441 ],
#        [ 7.6237593 ],
#        [14.27953176],
#        [16.54249439],
#        [11.72815232],
#        [17.42438424],
#        [16.04331146],
#        [13.47529259],
#        [19.98131016],
#        [ 7.96764088],
#        [18.44493602],
#        [18.92193305],
#        [22.74345573],
#        [ 9.74806001],
#        [16.09877623],
#        [ 8.06193099],
#        [16.31508884],
#        [19.31018644],
#        [22.33301643],
#        [20.75227047],
#        [16.41492542],
#        [22.32192348],
#        [16.15978748],
#        [15.66060454],
#        [19.09387384],
#        [10.09194159],
#        [22.92648948],
#        [21.05178023],
#        [18.34509943],
#        [14.71215697],
#        [17.57413912],
#        [22.83774584],
#        [ 8.0120127 ],
#        [ 9.16567992],
#        [11.16241166],
#        [ 7.92881554],
#        [16.2263452 ],
#        [15.27789763],
#        [ 9.09357572],
#        [12.19960287],
#        [16.79208586],
#        [22.70463039],
#        [19.84819471]])

# %%
y
# Out:
# array([[22.1],
#        [10.4],
#        [12. ],
#        [16.5],
#        [17.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [15.6],
#        [12.6],
#        [17.4],
#        [ 9.2],
#        [13.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [17.5],
#        [ 5.6],
#        [20.5],
#        [ 9.7],
#        [17. ],
#        [15. ],
#        [20.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [13.2],
#        [17.4],
#        [11.9],
#        [17.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [17.9],
#        [ 8.5],
#        [16.1],
#        [10.6],
#        [23.2],
#        [19.8],
#        [ 9.7],
#        [16.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
#        [23.8],
#        [18.4],
#        [ 8.1],
#        [24.2],
#        [20.7],
#        [14. ],
#        [16. ],
#        [11.3],
#        [11. ],
#        [13.4],
#        [18.9],
#        [22.3],
#        [18.3],
#        [12.4],
#        [ 8.8],
#        [11. ],
#        [17. ],
#        [ 8.7],
#        [ 6.9],
#        [14.2],
#        [ 5.3],
#        [11. ],
#        [11.8],
#        [17.3],
#        [11.3],
#        [13.6],
#        [21.7],
#        [20.2],
#        [12. ],
#        [16. ],
#        [12.9],
#        [16.7],
#        [14. ],
#        [ 7.3],
#        [19.4],
#        [22.2],
#        [11.5],
#        [16.9],
#        [16.7],
#        [20.5],
#        [25.4],
#        [17.2],
#        [16.7],
#        [23.8],
#        [19.8],
#        [19.7],
#        [20.7],
#        [15. ],
#        [ 7.2],
#        [12. ],
#        [ 5.3],
#        [19.8],
#        [18.4],
#        [21.8],
#        [17.1],
#        [20.9],
#        [14.6],
#        [12.6],
#        [12.2],
#        [ 9.4],
#        [15.9],
#        [ 6.6],
#        [15.5],
#        [ 7. ],
#        [16.6],
#        [15.2],
#        [19.7],
#        [10.6],
#        [ 6.6],
#        [11.9],
#        [24.7],
#        [ 9.7],
#        [ 1.6],
#        [17.7],
#        [ 5.7],
#        [19.6],
#        [10.8],
#        [11.6],
#        [ 9.5],
#        [20.8],
#        [ 9.6],
#        [20.7],
#        [10.9],
#        [19.2],
#        [20.1],
#        [10.4],
#        [12.3],
#        [10.3],
#        [18.2],
#        [25.4],
#        [10.9],
#        [10.1],
#        [16.1],
#        [11.6],
#        [16.6],
#        [16. ],
#        [20.6],
#        [ 3.2],
#        [15.3],
#        [10.1],
#        [ 7.3],
#        [12.9],
#        [16.4],
#        [13.3],
#        [19.9],
#        [18. ],
#        [11.9],
#        [16.9],
#        [ 8. ],
#        [17.2],
#        [17.1],
#        [20. ],
#        [ 8.4],
#        [17.5],
#        [ 7.6],
#        [16.7],
#        [16.5],
#        [27. ],
#        [20.2],
#        [16.7],
#        [16.8],
#        [17.6],
#        [15.5],
#        [17.2],
#        [ 8.7],
#        [26.2],
#        [17.6],
#        [22.6],
#        [10.3],
#        [17.3],
#        [20.9],
#        [ 6.7],
#        [10.8],
#        [11.9],
#        [ 5.9],
#        [19.6],
#        [17.3],
#        [ 7.6],
#        [14. ],
#        [14.8],
#        [25.5],
#        [18.4]])

# %%
model.score(y,y_pred)
# Out:
# -2.2654448204710067

# %%
import statsmodels.api as sm
x = df['TV']
y = df['Sales']
x2 = sm.add_constant(x)
temp = sm.OLS(y,x2)
est = temp.fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     856.2
# Date:                Sun, 02 Jan 2022   Prob (F-statistic):           7.93e-74
# Time:                        22:16:56   Log-Likelihood:                -448.99
# No. Observations:                 200   AIC:                             902.0
# Df Residuals:                     198   BIC:                             908.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.9748      0.323     21.624      0.000       6.339       7.611
# TV             0.0555      0.002     29.260      0.000       0.052       0.059
# ==============================================================================
# Omnibus:                        0.013   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.993   Jarque-Bera (JB):                0.043
# Skew:                          -0.018   Prob(JB):                        0.979
# Kurtosis:                       2.938   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\kanti\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
R-squared:                       0.812
    
    
    
    how to test ---> Linear Regression model 
                    R2
                    Adjusted R2
            
            
            95
            
            
            
            unknown data -- 
            
            
            
            training - perfect
            testing -- not perfect 
            
             overfitting
